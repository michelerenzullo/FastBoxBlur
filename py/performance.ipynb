# %%
import matplotlib.pyplot as plt
import numpy as np

opencv_1 = np.array([20.1649, 26.0333, 33.9403, 65.0182, 80.8133, 93.5737, 110.5312, 130.4317, 147.6296, 167.3393, 190.2543, 226.462, 244.7187, 266.2098, 300.4399, 326.8382, 357.5942, 386.107, 422.3306, 469.1044, 483.838, 529.4801, 562.801, 604.0435, 657.0389, 708.7842, 742.2173, 782.3401, 822.3826, 889.2292, 933.0428, 982.4348, 1027.5873, 1098.3586, 1144.7552, 1206.6835, 1274.1079, 1344.4944, 1381.4529, 1466.2569, 1512.8281, 1593.591, 1681.1392, 1797.3338, 1900.6065])
opencv_2 = np.array([39.2926, 50.9281, 65.4602, 131.7338, 158.8181, 194.9485, 223.8125, 260.8442, 299.2244, 338.4189, 376.6223, 426.5309, 466.714, 519.7231, 573.4439, 650.5794, 705.4136, 768.0905, 823.0944, 897.0298, 963.9168, 1065.4348, 1120.425, 1190.5674, 1278.3408, 1413.7926, 1459.4292, 1551.3144, 1693.1476, 1758.5151, 2049.9734, 1940.4425, 2055.1674, 2176.9393, 2346.5535, 2487.0064, 2527.4613, 2615.8682, 2779.097, 2855.9257, 2986.8779, 3134.326, 3312.0561, 3635.2109, 3970.2271])
fastboxblur_1 = np.array([15.8781, 20.0932, 26.065, 32.3864, 32.0619, 40.3524, 47.1886, 65.615, 63.0924, 68.7745, 78.458, 79.1471, 90.1017, 110.3483, 110.0679, 120.5687, 130.3754, 154.4712, 162.8164, 178.7224, 179.4744, 196.0581, 206.5961, 241.9417, 255.7518, 267.4663, 269.5067, 291.8561, 329.9426, 331.1334, 340.7583, 381.147, 396.423, 400.8126, 444.0444, 456.4877, 456.7437, 499.5256, 510.9184, 564.7435, 554.8295, 611.8535, 600.43, 654.3699, 650.7753])
fastboxblur_2 = np.array([23.637, 30.7188, 43.8297, 49.0005, 57.4251, 63.5413, 76.9266, 94.6398, 104.1602, 135.9449, 153.8076, 161.9904, 182.3866, 185.6716, 197.1612, 223.3954, 244.1099, 299.8448, 309.2385, 306.5074, 321.1385, 366.7432, 405.8393, 408.8887, 436.092, 479.445, 505.3083, 532.9883, 583.3067, 738.48, 748.1126, 653.5293, 708.0633, 717.5126, 799.5128, 791.9735, 849.2691, 896.799, 979.3398, 1025.5104, 1031.9895, 1039.2149, 1094.9302, 1157.327, 1180.7194])

sizes = np.array(['1500 x 1000', '1725 x 1150', '1950 x 1300', '2175 x 1450', '2400 x 1600', '2625 x 1750', '2850 x 1900', '3075 x 2050', '3300 x 2200', '3525 x 2350', '3750 x 2500', '3975 x 2650', '4200 x 2800', '4425 x 2950', '4650 x 3100', '4875 x 3250', '5100 x 3400', '5325 x 3550', '5550 x 3700', '5775 x 3850', '6000 x 4000', '6225 x 4150', '6450 x 4300', '6675 x 4450', '6900 x 4600', '7125 x 4750', '7350 x 4900', '7575 x 5050', '7800 x 5200', '8025 x 5350', '8250 x 5500', '8475 x 5650', '8700 x 5800', '8925 x 5950', '9150 x 6100', '9375 x 6250', '9600 x 6400', '9825 x 6550', '10050 x 6700', '10275 x 6850', '10500 x 7000', '10725 x 7150', '10950 x 7300', '11175 x 7450', '11400 x 7600'])

plt.ylabel('time(ms)')
plt.xlabel('size')
plt.title('cv::blur vs fastboxblur - RGB 24bits images - boxsize = 2 * width - 1')

plt.plot(sizes, opencv_2, c='b', label='cv::blur 2 pass')
plt.plot(sizes, opencv_1, c='r', label='cv::blur 1 pass')
plt.grid(linewidth=0.07)
plt.plot(sizes, fastboxblur_2, c='black', label='fastboxblur 2 pass')
plt.plot(sizes, fastboxblur_1, c='purple', label='fastboxblur 1 pass')
plt.xticks(rotation = 90)

plt.legend(loc="upper left")
plt.gcf().set_size_inches(25, 15)
#plt.savefig('bench.png', dpi=200)

#plt.show()
